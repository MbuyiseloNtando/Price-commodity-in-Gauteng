# %%
import pandas as pd
import matplotlib.pyplot 
import seaborn as sns
df=pd.read_csv('https://data.humdata.org/dataset/7fb6fbc6-69b7-4b90-ace1-ca04dc6d53ac/resource/33de764b-6359-4a65-8df6-75281ade843d/download/wfp_food_prices_zaf.csv') 
df.head(5)
# Out:
#          date      admin1                           admin2            market  \
# 0       #date  #adm1+name                       #adm2+name  #loc+market+name
# 1  2000-01-15     Gauteng  West Rand District Municipality       Randfontein
# 2  2000-01-15     Gauteng  West Rand District Municipality       Randfontein
# 3  2000-01-15     Gauteng  West Rand District Municipality       Randfontein
# 4  2000-02-15     Gauteng  West Rand District Municipality       Randfontein
#
#    latitude longitude            category       commodity        unit  \
# 0  #geo+lat  #geo+lon          #item+type      #item+name  #item+unit
# 1   -26.199    27.669  cereals and tubers   Maize (white)          KG
# 2   -26.199    27.669  cereals and tubers  Maize (yellow)          KG
# 3   -26.199    27.669  cereals and tubers           Wheat          KG
# 4   -26.199    27.669  cereals and tubers   Maize (white)          KG
#
#           priceflag         pricetype   currency   price    usdprice
# 0  #item+price+flag  #item+price+type  #currency  #value  #value+usd
# 1            actual         Wholesale        ZAR     0.8      0.1289
# 2            actual         Wholesale        ZAR    0.86      0.1378
# 3            actual         Wholesale        ZAR    0.65      0.1042
# 4            actual         Wholesale        ZAR     0.8      0.1265

# %% [markdown]
# # Droping the first frow

# %%
df.drop(df.index[[0]], inplace=True)

# %%
df.columns
# Out:
# Index(['admin1', 'admin2', 'market', 'latitude', 'longitude', 'category',
#        'commodity', 'unit', 'priceflag', 'pricetype', 'currency', 'price',
#        'usdprice', 'year', 'month'],
#       dtype='object')

# %% [markdown]
# ####Checking dataframe information

# %%
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811 entries, 0 to 810
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       811 non-null    object
#  1   admin1     811 non-null    object
#  2   admin2     811 non-null    object
#  3   market     811 non-null    object
#  4   latitude   811 non-null    object
#  5   longitude  811 non-null    object
#  6   category   811 non-null    object
#  7   commodity  811 non-null    object
#  8   unit       811 non-null    object
#  9   priceflag  811 non-null    object
#  10  pricetype  811 non-null    object
#  11  currency   811 non-null    object
#  12  price      811 non-null    object
#  13  usdprice   811 non-null    object
# dtypes: object(14)
# memory usage: 88.8+ KB
#               date   admin1                           admin2       market  \
# count          811      811                              811          811
# unique         271        2                                2            2
# top     2011-03-15  Gauteng  West Rand District Municipality  Randfontein
# freq             3      810                              810          810
#
#        latitude longitude            category      commodity unit priceflag  \
# count       811       811                 811            811  811       811
# unique        2         2                   2              4    2         2
# top     -26.199    27.669  cereals and tubers  Maize (white)   KG    actual
# freq        810       810                 810            270  810       810
#
#         pricetype currency price usdprice
# count         811      811   811      811
# unique          2        2   363      691
# top     Wholesale      ZAR  0.88   0.2323
# freq          810      810     8        5

# %% [markdown]
# Checking for null values

# %%
df.isna().sum()
# Out:
# date         0
# admin1       0
# admin2       0
# market       0
# latitude     0
# longitude    0
# category     0
# commodity    0
# unit         0
# priceflag    0
# pricetype    0
# currency     0
# price        0
# usdprice     0
# dtype: int64

# %% [markdown]
# Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Splitting the date column to year and month

# %%
df['year']=df['date'].str.split(pat='-').str[0].astype('int')
df['month']=df['date'].str.split(pat='-').str[1].astype('int') 
df.drop(columns='date', inplace=True)

# %%
df.head()
# Out:
#     admin1                           admin2       market latitude longitude  \
# 1  Gauteng  West Rand District Municipality  Randfontein  -26.199    27.669
# 2  Gauteng  West Rand District Municipality  Randfontein  -26.199    27.669
# 3  Gauteng  West Rand District Municipality  Randfontein  -26.199    27.669
# 4  Gauteng  West Rand District Municipality  Randfontein  -26.199    27.669
# 5  Gauteng  West Rand District Municipality  Randfontein  -26.199    27.669
#
#              category       commodity unit priceflag  pricetype currency  \
# 1  cereals and tubers   Maize (white)   KG    actual  Wholesale      ZAR
# 2  cereals and tubers  Maize (yellow)   KG    actual  Wholesale      ZAR
# 3  cereals and tubers           Wheat   KG    actual  Wholesale      ZAR
# 4  cereals and tubers   Maize (white)   KG    actual  Wholesale      ZAR
# 5  cereals and tubers  Maize (yellow)   KG    actual  Wholesale      ZAR
#
#   price usdprice  year  month
# 1   0.8   0.1289  2000      1
# 2  0.86   0.1378  2000      1
# 3  0.65   0.1042  2000      1
# 4   0.8   0.1265  2000      2
# 5  0.83   0.1311  2000      2

# %% [markdown]
# # Changing numeric column's dtypes to floats

# %%
df=df.astype({'latitude':'float', 'longitude':'float','price' :'float','usdprice' :'float'})

# %% [markdown]
# # Renaming the 1st two columns

# %%
df=df.rename(columns ={'admin1':'province','admin2':'municipality'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810 entries, 1 to 810
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   province      810 non-null    object
#  1   municipality  810 non-null    object
#  2   market        810 non-null    object
#  3   latitude      810 non-null    float64
#  4   longitude     810 non-null    float64
#  5   category      810 non-null    object
#  6   commodity     810 non-null    object
#  7   unit          810 non-null    object
#  8   priceflag     810 non-null    object
#  9   pricetype     810 non-null    object
#  10  currency      810 non-null    object
#  11  price         810 non-null    float64
#  12  usdprice      810 non-null    float64
#  13  year          810 non-null    int64
#  14  month         810 non-null    int64
# dtypes: float64(4), int64(2), object(9)
# memory usage: 95.1+ KB

# %% [markdown]
# The average price of commodity for each province each year?

# %%
df.corr(numeric_only =True)
# Out:
#            latitude  longitude     price  usdprice      year     month
# latitude        NaN        NaN       NaN       NaN       NaN       NaN
# longitude       NaN        NaN       NaN       NaN       NaN       NaN
# price           NaN        NaN  1.000000  0.781687  0.788365 -0.013142
# usdprice        NaN        NaN  0.781687  1.000000  0.476075 -0.014970
# year            NaN        NaN  0.788365  0.476075  1.000000 -0.033423
# month           NaN        NaN -0.013142 -0.014970 -0.033423  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
df['year'].value_counts()
# Out:
# year
# 2000    36
# 2012    36
# 2021    36
# 2020    36
# 2019    36
# 2018    36
# 2017    36
# 2016    36
# 2015    36
# 2014    36
# 2013    36
# 2011    36
# 2001    36
# 2010    36
# 2009    36
# 2008    36
# 2007    36
# 2006    36
# 2005    36
# 2004    36
# 2003    36
# 2002    36
# 2022    18
# Name: count, dtype: int64

# %%
import numpy as np
grouped = df.groupby('year')
df_by_year=grouped["price"].agg(lambda x: np.mean(x)) 
df_by_year
# Out:
# year
# 2000    0.708333
# 2001    1.004722
# 2002    1.594444
# 2003    1.012778
# 2004    1.030833
# 2005    0.784722
# 2006    1.251111
# 2007    2.021667
# 2008    2.392778
# 2009    1.819722
# 2010    1.627500
# 2011    2.276944
# 2012    2.652778
# 2013    2.670556
# 2014    2.780833
# 2015    3.210556
# 2016    4.068611
# 2017    2.827222
# 2018    2.802222
# 2019    3.338333
# 2020    3.708056
# 2021    4.019444
# 2022    5.100000
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt
df_by_year.plot(kind='line')
plt.title("Average comodity prices per year")
plt.ylabel('Avarage Price')
# Out:
# Text(0, 0.5, 'Avarage Price')

# %%
df['commodity'].value_counts()
# Out:
# commodity
# Maize (white)     270
# Maize (yellow)    270
# Wheat             270
# Name: count, dtype: int64

# %%
# Out:
#                        year
# commodity
# Maize (white)   2010.755556
# Maize (yellow)  2010.755556
# Wheat           2010.755556
